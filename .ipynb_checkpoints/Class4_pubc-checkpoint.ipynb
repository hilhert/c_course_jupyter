// %% [markdown]
// <p style="text-align: center;font-size: 33px;font-weight:bold;"> <span style="color:DarkGoldenrod">&lt;&lt; C程序的基本要素 &gt;&gt;</span></p>
// <p style="text-align: center;font-size: 25px;font-weight:bold;"> <span style="color:Goldenrod">&lt;&lt; Programming Basics using C Language  &gt;&gt;</span></p>
// <p style="text-align: right; font-size:15px; font-weight:normal">----千里之行，基于硅步</p>

// %% [markdown]
// ### 运算符与表达式
// * 算术运算符与算术表达式
// * 逻辑、关系运算符与逻辑、关系表达式
// * 逗号运算符与逗号表达式
// * 按位运算符
// * 强制类型转换与隐含类型转换
// * 运算符的优先级与结合性

// %% [markdown]
// #### 算术运算符与算术表达式
// +、-、*、/、%（取余）<br>
// * 浮点数变量与整型变量运算，结果为浮点数
// * 等长无符号整形与有符号整形运算，结果是什么类型就是什么类型
// * 短类型变量与长类型变量运算，结果为长类型
// * 算术表达式的优先级与数学定义一样。
// * 多个+，-算术运算符的优先级为从右到左
// * 多个*，/，%算术运算符的优先级从左到右

// %%
#include <stdio.h>
int main(){
    int   ia =33;
    float fb = 44.66;
    __typeof__ (ia+fb) c=ia+fb;
    printf("%f\n",c);
 /*   
    unsigned char ca=22;
    signed   char cb=-46;
    printf("%d\n",ca+cb);
    
    short sc = 517;
    char  cd =  124;
    printf("%d\n",sc+cd);
    
   
    printf("%f\n",100.0/4/3-3*6+44%16);
*/
}
// Out:
// 77.660004
// -24
// 641
// 2.333333

// %% [markdown]
// * 例：判断某一个年份是否为闰年
// 解析： 当100不能够整除该年份时，若4能够整除该年份则为闰年<br>
//       或400能够整除该年份时，亦为闰年

// %%
#include <stdio.h>
int main(){
    int year = 2018;
    printf("Year %d is %s leap year",year,(year%4==0&&year%100!=0)||year%400==0?"a":"not a");
    return 0;
}
// Out:
// Year 2018 is not a leap year

// %% [markdown]
// #### 逻辑、关系运算符与逻辑、关系表达式
// * 基本逻辑运算符(l-op)
// ！、&&、|| <br>
// (expr)&&(!expr) $\equiv$ 0 <br>
// (expr)||(!expr)  $\equiv$ 1 <br>
// (expr)的值要么为0，要么为1<br>
// expr 为嵌套定义，永远有拆分为expr1(!、&&、||、==)expr2 <br>
// 二元基本逻辑运算符&&、||的运算次序为从左向右<br>
// (expr1)&&(expr2) 一旦确定（expr1）的值为0，则确定整个表达式的值为0<br>
// (expr1)||(expr2) 一旦确定（expr1）的值为1，则确定整个表达式的值为1<br>
// !(expr)的运算次序为从右向左<br>
// * 关系运算符(r-op)
// \>、\<、==、\<=、\>=   <br>
// r-expr 的运算结果才应该代入expr，expr不该代入r-expr<br>
// (r-expr1) r-op (r-expr2) 有定义无意义 <br>
// !(r-expr) 或 (r-expr1) l-op (r-expr2) 才有意义<br>
// 永远不要花费大量的时间去抠细节，用（）写清楚逻辑关系就可以<br>
// * 条件表达式
// a?b:c;<br>
// a 的值只有(0,1), 可写为`关系表达式`、`逻辑表达式`、`由关系表达式组成的逻辑表达式`<br>
// (a?b:c) 当a的值为1时，表达式的值为b,否则表达式的值为0 <br>

// %%
//demo htoa_m   将16进制数表达的字符串转换为整形
#include <stdio.h>
int lower(int c)
{
if (c >= 'A' && c <= 'F')
return c + 'a' - 'A';
else
return c;
}
int htoa_m(char hex[]){
    int digit=0,tail;
    for(int i=0;hex[i]!='\0';i++,digit=digit+tail){
       
       hex[i]=lower(hex[i]); 
        
       tail  = (hex[i]>='a')?(hex[i]-'a'+10):(hex[i]-'0');
       digit = digit*16;
       //digit = digit<<4;
       
      }
    
    return digit;
}

int main(){
    char hex[]="1Ff";
    printf("%d",htoa_m(hex));
    return 0;
}
// Out:
// 511

// %%
#### 逗号运算符与逗号表达式
* 逗号运算符号是C语言中的特殊运算符号<br>
* exp1,exp2,exp3 等价于exp1; exp2; return exp3<br>
* 一般用来缩短代码，使代码看起来紧凑<br>

// %%
#include <stdio.h>
int main(){
    int i=0;
    printf("%d",(i++,i--)); //实际运行结果与k&r书中的描述不符合
    return 0;
}
// Out:
// 1

// %% [markdown]
// #### 赋值运算符号与赋值表达式
// * 赋值表达式的值为等号右边的运算结果
// * 赋值表达式的运算次序为从到左
// * 赋值表达式的作用同样是缩短代码
//
// * 自增、自减运算符号<br>
//   i++、i--、++i、--i<br>
//   a+=b、a-=b<br>
// * 自运算<br>
//   a = a (op) b  当$\text{op} \notin \{=,\text{r-op},\text{l-op}\}$时，可写为：<br>
//   a(op)=b<br>

// %% [markdown]
// #### 按位运算符
// ～、|、&、^、\>\>、\<\< <br>
// 按位运算符可理解位变量的位操作符号<br>
// 一元操作符~的含义为`变量的各二进制位均取反`<br>
// 二元非对称`位操作符`\>\>的含义为`变量的各二进制位均向右移动n位，n为右元`<br>
// 二元非对称`位操作符`\>\>的含义为`变量的各二进制位均向左移动n位，n为左元`<br>
// 二元对称`位操作符` & 的含义为`将左、右元各对应二进制位进行与运算`<br>
// 二元对称`位操作符` | 的含义为`将左、右元各对应二进制位进行或运算`<br>
// 二元对称`位操作符` ^ 的含义为`将左、右元各对应二进制位进行异或运算`<br>
// 按位运算符可参与自运算<br>

// %%
#include <stdio.h>
int main(){
    int a = 89;
    int b = -43;
    a^=b;
    b^=a;
    a^=b;
    printf("a is %d now; b is %d now\n",a,b);
    printf("~a is %d\n",~a);
    printf("~(a-1) is %d\n",~(a-1));
    printf("a >>1 is %d\n",a>>1);
    printf("a <<1 is %d\n",a<<1);//不要简单的以为就是*2. 
    printf("a is %x, a & 0X000000FF is %x",a,a&0X000000FF);
    
}
// Out:
// a is -43 now; b is 89 now
// ~a is 42
// ~(a-1) is 43
// a >>1 is -22
// a <<1 is -86
// a is ffffffd5, a & 0X000000FF is d5

// %% [markdown]
// #### 强制类型转换
// 算术表达式的结果类型总取表达式中最复杂、位长最长的类型<br>
// 为达到某种需要，有时许需要降低变量类型的复杂度于长度<br>
// 浮点数转整型的结果为向0取整<br>
// 长类型转短类型的结果为取最后n位，n位断类型字长<br>
// double转float仅仅降低精度，不需详细讨论<br>

// %%
#include <stdio.h>
int main(){
    short a  =65535;
    printf("%d\n",(char)a);
    
    double b = -76.834;
    printf("%d\n",(int)b);    
}
// Out:
// -1
// -76

// %% [markdown]
// #### 运算符的优先级与结合性
// 不需要了解的太清楚，不行就加()确定次序<br>
// <table>
// <tr><th>符号</th> <th>计算次序</th></tr>
// <tr><td> !&nbsp;&nbsp;&nbsp;&nbsp; ~&nbsp;&nbsp;&nbsp;&nbsp; ++&nbsp;&nbsp;&nbsp;&nbsp; --&nbsp;&nbsp;&nbsp;&nbsp; +&nbsp;&nbsp;&nbsp;&nbsp; -&nbsp;&nbsp;&nbsp;&nbsp; *&nbsp;&nbsp;&nbsp;&nbsp; (type)&nbsp;&nbsp;&nbsp;&nbsp; sizeof</td><td> 从右至左</td></tr>
// <tr><td>=&nbsp;&nbsp;&nbsp;&nbsp; +=&nbsp;&nbsp;&nbsp;&nbsp; -=&nbsp;&nbsp;&nbsp;&nbsp; *=&nbsp;&nbsp;&nbsp;&nbsp; =&nbsp;&nbsp;&nbsp;&nbsp; %=&nbsp;&nbsp;&nbsp;&nbsp; &=&nbsp;&nbsp;&nbsp;&nbsp; ^=&nbsp;&nbsp;&nbsp;&nbsp; |=&nbsp;&nbsp;&nbsp;&nbsp; &lt;&lt;=&nbsp;&nbsp;&nbsp;&nbsp; &gt;&gt;=</td><td>从右至左</td></tr>
// <tr><td>, </td><td>编译器行为</td></tr>
// <tr><td>其他</td><td>从左至右</td></tr>
// <table>
//
// ```C
//     int b =0;
//     int a = g()+f();  //合法不合理，先计算g或先计算f是编译器行为
//
//     char c[]="abc";
//     char c[b]=b++ ;  //合法不合理，b先自增还是先取b的值是编译器型位
//
//     printf("%d,%f\n",n++,pow(2,n)); //合法不合理，n++与pow(2,n)的先后次序还是编译器行为
//
// ```

// %% [markdown]
// #### 关于指针、数组的补充
// * char a[m][n];    &nbsp;&nbsp;&nbsp;&nbsp; m行、n列的二维数组，
// * char (*a)[n];    &nbsp;&nbsp;&nbsp;&nbsp; 数组指针，a+k代表a[m][n]的第(k+1)行。
// * char a[];        声明为函数变量时，只有实参传递，没有形参传递
// ```C
// #include <stdio.h>
// int* cumsum(int a[],int K){
//     for(int i=1;i<K;i++)
//         a[i]+=a[i-1];
//     return a;
// }
// int main(){
//     int b[6]={0,1,2,3,4,5};
//     int* r  =cumsum(b,6);
//     printf("r%sb\n",r==b?" is equal to":" is not equal to ");
//     for(int i=0;i<6;i++) printf("%d ",b[i]); printf("\n");
//     return 0;
// }
// ```

// %%
#include <stdio.h>
int* cumsum(int a[],int K){
    for(int i=1;i<K;i++)
        a[i]+=a[i-1];
    K=K-1;
    return a;
}
int main(){
    int b[6]={0,1,2,3,4,5};
    int K=6;
    int* r  =cumsum(b,K);
    printf("r%s b\n",r==b?" is equal to":" is not equal to ");
    for(int i=0;i<6;i++) printf("%d ",b[i]); printf("\n");
    printf("K%s 6\n",K==6?" is equal to":" is not equal to ");
    return 0;
}
// Out:
// r is equal to b
// 0 1 3 6 10 15
// K is equal to 6

// %% [markdown]
// #### 习题： 尝试自行解释以下代码

// %%
//%cflags:-lm
//Gauss-Seidal 高斯-塞尔德算法（示意而已！）
#include <stdio.h>
#include <math.h>
#include <malloc.h>
void Gauss_Siedal1(const float (*A)[5],const float* Y,float x[],int K){
float s=0;
for(int i=0;i<K;i++){
    for(int j=0;j<K;j++){
        if(!(j==i)) s+=A[i][j]*x[j];
    }
    x[i]= (Y[i]-s)/A[i][i];
    s   = 0;
    }
}

float evalue_AXY(const float (*A)[5],const float* Y,float x[],int K){
    float sum  = 0;
    float s    = 0;
    for(int i=0;i<K;i++){
        for(int j=0;j<K;j++) s+=A[i][j]*x[j];
        s    = pow(Y[i]-s,2);
        sum += s;
        s    = 0;
    }
    return sum;
}


int main(){
    float A[][5] ={{5.7,0.5,0.7,2.3,4.4},
                  {0.5,5.7,0.3,0.2,3.6},
                  {0.7,0.3,5.7,0.3,1.5},
                  {2.3,0.2,0.3,5.7,0.7},
                  {4.4,3.6,1.5,0.7,5.7}};
    float Y[]   = {0.5,1.1,2.4,4.5,0.2};
    
    float x[5];
    for(int i=0;i<5;i++) x[i]=0;
    float eval;
    for(int i=0;i<100;i++){
    Gauss_Siedal1(A,Y,x,5);
    eval = evalue_AXY(A,Y,x,5);
    printf("x is ");
    for(int j=0;j<5;j++) printf("%f ", x[j]);
    printf("\n");
    printf("|| Y-Ax||^2 is %f after %d iteration!\n",eval,i+1);    
    }
    
    return 0;
}
// Out:
// x is 0.087719 0.185288 0.400528 0.726496 -0.344270
// || Y-Ax||^2 is 1.375680 after 1 iteration!
// x is -0.005117 0.364294 0.454868 0.797094 -0.408634
// || Y-Ax||^2 is 0.048271 after 2 iteration!
// x is -0.006295 0.399710 0.466371 0.803626 -0.433922
// || Y-Ax||^2 is 0.014019 after 3 iteration!
// x is 0.006070 0.413762 0.470424 0.801036 -0.453090
// || Y-Ax||^2 is 0.012188 after 4 iteration!
// x is 0.020182 0.424509 0.473306 0.797167 -0.471054
// || Y-Ax||^2 is 0.011606 after 5 iteration!
// x is 0.034313 0.434599 0.475971 0.793177 -0.488546
// || Y-Ax||^2 is 0.011146 after 6 iteration!
// x is 0.048214 0.444427 0.478559 0.789235 -0.505681
// || Y-Ax||^2 is 0.010715 after 7 iteration!
// x is 0.061851 0.454054 0.481095 0.785365 -0.522480
// || Y-Ax||^2 is 0.010303 after 8 iteration!
// x is 0.075225 0.463494 0.483580 0.781570 -0.538954
// || Y-Ax||^2 is 0.009908 after 9 iteration!
// x is 0.088339 0.472750 0.486017 0.777848 -0.555107
// || Y-Ax||^2 is 0.009527 after 10 iteration!
// x is 0.101199 0.481827 0.488407 0.774198 -0.570948
// || Y-Ax||^2 is 0.009161 after 11 iteration!
// x is 0.113810 0.490727 0.490750 0.770619 -0.586481
// || Y-Ax||^2 is 0.008809 after 12 iteration!
// x is 0.126176 0.499455 0.493048 0.767110 -0.601712
// || Y-Ax||^2 is 0.008471 after 13 iteration!
// x is 0.138302 0.508014 0.495302 0.763669 -0.616649
// || Y-Ax||^2 is 0.008145 after 14 iteration!
// x is 0.150193 0.516406 0.497512 0.760294 -0.631295
// || Y-Ax||^2 is 0.007832 after 15 iteration!
// x is 0.161853 0.524636 0.499678 0.756985 -0.645658
// || Y-Ax||^2 is 0.007531 after 16 iteration!
// x is 0.173287 0.532706 0.501803 0.753740 -0.659742
// || Y-Ax||^2 is 0.007242 after 17 iteration!
// x is 0.184499 0.540619 0.503887 0.750558 -0.673552
// || Y-Ax||^2 is 0.006964 after 18 iteration!
// x is 0.195494 0.548380 0.505930 0.747438 -0.687095
// || Y-Ax||^2 is 0.006696 after 19 iteration!
// x is 0.206275 0.555989 0.507934 0.744378 -0.700375
// || Y-Ax||^2 is 0.006439 after 20 iteration!
// x is 0.216848 0.563451 0.509898 0.741378 -0.713398
// || Y-Ax||^2 is 0.006192 after 21 iteration!
// x is 0.227215 0.570768 0.511825 0.738436 -0.726168
// || Y-Ax||^2 is 0.005954 after 22 iteration!
// x is 0.237381 0.577944 0.513714 0.735550 -0.738690
// || Y-Ax||^2 is 0.005725 after 23 iteration!
// x is 0.247350 0.584980 0.515567 0.732721 -0.750969
// || Y-Ax||^2 is 0.005505 after 24 iteration!
// x is 0.257126 0.591879 0.517383 0.729947 -0.763010
// || Y-Ax||^2 is 0.005294 after 25 iteration!
// x is 0.266712 0.598645 0.519165 0.727226 -0.774818
// || Y-Ax||^2 is 0.005090 after 26 iteration!
// x is 0.276112 0.605280 0.520912 0.724559 -0.786396
// || Y-Ax||^2 is 0.004894 after 27 iteration!
// x is 0.285330 0.611785 0.522625 0.721943 -0.797750
// || Y-Ax||^2 is 0.004707 after 28 iteration!
// x is 0.294369 0.618165 0.524304 0.719378 -0.808884
// || Y-Ax||^2 is 0.004526 after 29 iteration!
// x is 0.303233 0.624421 0.525952 0.716862 -0.819802
// || Y-Ax||^2 is 0.004352 after 30 iteration!
// x is 0.311924 0.630556 0.527567 0.714396 -0.830508
// || Y-Ax||^2 is 0.004185 after 31 iteration!
// x is 0.320447 0.636571 0.529151 0.711977 -0.841006
// || Y-Ax||^2 is 0.004024 after 32 iteration!
// x is 0.328805 0.642470 0.530704 0.709605 -0.851301
// || Y-Ax||^2 is 0.003869 after 33 iteration!
// x is 0.337001 0.648254 0.532227 0.707279 -0.861396
// || Y-Ax||^2 is 0.003721 after 34 iteration!
// x is 0.345037 0.653927 0.533720 0.704998 -0.871295
// || Y-Ax||^2 is 0.003578 after 35 iteration!
// x is 0.352918 0.659489 0.535185 0.702762 -0.881002
// || Y-Ax||^2 is 0.003440 after 36 iteration!
// x is 0.360646 0.664943 0.536621 0.700568 -0.890521
// || Y-Ax||^2 is 0.003308 after 37 iteration!
// x is 0.368224 0.670292 0.538029 0.698418 -0.899855
// || Y-Ax||^2 is 0.003181 after 38 iteration!
// x is 0.375655 0.675536 0.539410 0.696309 -0.909008
// || Y-Ax||^2 is 0.003059 after 39 iteration!
// x is 0.382942 0.680679 0.540764 0.694241 -0.917983
// || Y-Ax||^2 is 0.002941 after 40 iteration!
// x is 0.390087 0.685723 0.542092 0.692213 -0.926785
// || Y-Ax||^2 is 0.002828 after 41 iteration!
// x is 0.397094 0.690668 0.543394 0.690225 -0.935416
// || Y-Ax||^2 is 0.002720 after 42 iteration!
// x is 0.403965 0.695518 0.544671 0.688275 -0.943879
// || Y-Ax||^2 is 0.002615 after 43 iteration!
// x is 0.410703 0.700273 0.545923 0.686363 -0.952178
// || Y-Ax||^2 is 0.002515 after 44 iteration!
// x is 0.417310 0.704936 0.547151 0.684488 -0.960316
// || Y-Ax||^2 is 0.002418 after 45 iteration!
// x is 0.423789 0.709509 0.548355 0.682649 -0.968297
// || Y-Ax||^2 is 0.002325 after 46 iteration!
// x is 0.430142 0.713993 0.549536 0.680846 -0.976122
// || Y-Ax||^2 is 0.002236 after 47 iteration!
// x is 0.436372 0.718390 0.550693 0.679078 -0.983796
// || Y-Ax||^2 is 0.002150 after 48 iteration!
// x is 0.442481 0.722702 0.551829 0.677344 -0.991321
// || Y-Ax||^2 is 0.002067 after 49 iteration!
// x is 0.448472 0.726930 0.552942 0.675644 -0.998700
// || Y-Ax||^2 is 0.001988 after 50 iteration!
// x is 0.454346 0.731076 0.554034 0.673977 -1.005935
// || Y-Ax||^2 is 0.001911 after 51 iteration!
// x is 0.460106 0.735142 0.555104 0.672342 -1.013031
// || Y-Ax||^2 is 0.001838 after 52 iteration!
// x is 0.465755 0.739129 0.556154 0.670739 -1.019988
// || Y-Ax||^2 is 0.001767 after 53 iteration!
// x is 0.471294 0.743038 0.557183 0.669167 -1.026811
// || Y-Ax||^2 is 0.001700 after 54 iteration!
// x is 0.476726 0.746872 0.558192 0.667626 -1.033502
// || Y-Ax||^2 is 0.001634 after 55 iteration!
// x is 0.482052 0.750631 0.559182 0.666114 -1.040062
// || Y-Ax||^2 is 0.001572 after 56 iteration!
// x is 0.487275 0.754317 0.560153 0.664632 -1.046496
// || Y-Ax||^2 is 0.001511 after 57 iteration!
// x is 0.492397 0.757932 0.561105 0.663178 -1.052804
// || Y-Ax||^2 is 0.001453 after 58 iteration!
// x is 0.497419 0.761477 0.562038 0.661753 -1.058991
// || Y-Ax||^2 is 0.001397 after 59 iteration!
// x is 0.502344 0.764953 0.562953 0.660355 -1.065057
// || Y-Ax||^2 is 0.001344 after 60 iteration!
// x is 0.507174 0.768362 0.563851 0.658985 -1.071006
// || Y-Ax||^2 is 0.001292 after 61 iteration!
// x is 0.511909 0.771704 0.564731 0.657641 -1.076839
// || Y-Ax||^2 is 0.001242 after 62 iteration!
// x is 0.516553 0.774982 0.565594 0.656323 -1.082559
// || Y-Ax||^2 is 0.001195 after 63 iteration!
// x is 0.521107 0.778196 0.566440 0.655030 -1.088168
// || Y-Ax||^2 is 0.001149 after 64 iteration!
// x is 0.525572 0.781347 0.567270 0.653763 -1.093668
// || Y-Ax||^2 is 0.001105 after 65 iteration!
// x is 0.529951 0.784438 0.568084 0.652521 -1.099062
// || Y-Ax||^2 is 0.001062 after 66 iteration!
// x is 0.534245 0.787469 0.568882 0.651302 -1.104351
// || Y-Ax||^2 is 0.001021 after 67 iteration!
// x is 0.538456 0.790440 0.569664 0.650107 -1.109537
// || Y-Ax||^2 is 0.000982 after 68 iteration!
// x is 0.542585 0.793355 0.570431 0.648935 -1.114623
// || Y-Ax||^2 is 0.000944 after 69 iteration!
// x is 0.546634 0.796212 0.571184 0.647786 -1.119610
// || Y-Ax||^2 is 0.000908 after 70 iteration!
// x is 0.550604 0.799014 0.571921 0.646659 -1.124501
// || Y-Ax||^2 is 0.000873 after 71 iteration!
// x is 0.554497 0.801762 0.572645 0.645555 -1.129296
// || Y-Ax||^2 is 0.000840 after 72 iteration!
// x is 0.558315 0.804457 0.573354 0.644471 -1.133998
// || Y-Ax||^2 is 0.000807 after 73 iteration!
// x is 0.562058 0.807099 0.574050 0.643409 -1.138610
// || Y-Ax||^2 is 0.000776 after 74 iteration!
// x is 0.565729 0.809690 0.574732 0.642367 -1.143131
// || Y-Ax||^2 is 0.000747 after 75 iteration!
// x is 0.569329 0.812231 0.575401 0.641345 -1.147566
// || Y-Ax||^2 is 0.000718 after 76 iteration!
// x is 0.572859 0.814722 0.576057 0.640343 -1.151914
// || Y-Ax||^2 is 0.000690 after 77 iteration!
// x is 0.576321 0.817165 0.576701 0.639361 -1.156178
// || Y-Ax||^2 is 0.000664 after 78 iteration!
// x is 0.579715 0.819561 0.577331 0.638398 -1.160359
// || Y-Ax||^2 is 0.000638 after 79 iteration!
// x is 0.583044 0.821911 0.577950 0.637453 -1.164459
// || Y-Ax||^2 is 0.000614 after 80 iteration!
// x is 0.586308 0.824214 0.578557 0.636527 -1.168479
// || Y-Ax||^2 is 0.000590 after 81 iteration!
// x is 0.589509 0.826473 0.579151 0.635618 -1.172422
// || Y-Ax||^2 is 0.000567 after 82 iteration!
// x is 0.592647 0.828689 0.579735 0.634728 -1.176288
// || Y-Ax||^2 is 0.000546 after 83 iteration!
// x is 0.595725 0.830861 0.580307 0.633854 -1.180079
// || Y-Ax||^2 is 0.000525 after 84 iteration!
// x is 0.598743 0.832991 0.580867 0.632998 -1.183796
// || Y-Ax||^2 is 0.000505 after 85 iteration!
// x is 0.601703 0.835080 0.581417 0.632158 -1.187441
// || Y-Ax||^2 is 0.000485 after 86 iteration!
// x is 0.604605 0.837128 0.581957 0.631334 -1.191016
// || Y-Ax||^2 is 0.000467 after 87 iteration!
// x is 0.607451 0.839137 0.582486 0.630527 -1.194521
// || Y-Ax||^2 is 0.000449 after 88 iteration!
// x is 0.610241 0.841106 0.583004 0.629735 -1.197959
// || Y-Ax||^2 is 0.000431 after 89 iteration!
// x is 0.612978 0.843038 0.583513 0.628958 -1.201329
// || Y-Ax||^2 is 0.000415 after 90 iteration!
// x is 0.615661 0.844932 0.584011 0.628197 -1.204635
// || Y-Ax||^2 is 0.000399 after 91 iteration!
// x is 0.618292 0.846789 0.584500 0.627450 -1.207876
// || Y-Ax||^2 is 0.000384 after 92 iteration!
// x is 0.620873 0.848610 0.584980 0.626718 -1.211054
// || Y-Ax||^2 is 0.000369 after 93 iteration!
// x is 0.623403 0.850396 0.585450 0.626000 -1.214170
// || Y-Ax||^2 is 0.000355 after 94 iteration!
// x is 0.625884 0.852147 0.585911 0.625295 -1.217227
// || Y-Ax||^2 is 0.000341 after 95 iteration!
// x is 0.628317 0.853864 0.586363 0.624605 -1.220224
// || Y-Ax||^2 is 0.000328 after 96 iteration!
// x is 0.630703 0.855548 0.586807 0.623928 -1.223162
// || Y-Ax||^2 is 0.000315 after 97 iteration!
// x is 0.633042 0.857199 0.587241 0.623264 -1.226044
// || Y-Ax||^2 is 0.000303 after 98 iteration!
// x is 0.635336 0.858818 0.587668 0.622613 -1.228870
// || Y-Ax||^2 is 0.000292 after 99 iteration!
// x is 0.637586 0.860406 0.588086 0.621974 -1.231641
// || Y-Ax||^2 is 0.000280 after 100 iteration!

// %%
// 选择排序法
#include <stdio.h>
void print_n(int arr[], int n){
for(int i=0;i<n;i++) printf("%d  ",arr[i]);
printf("\n");
}
void selectn(int arr[],int n){
for(int i=0;i<n;i++)
if(arr[i]>arr[n]){
int temp = arr[i];
arr[i]   = arr[n];
arr[n]     = temp;
} 
}
int main(){
int arr[17]={45,23,12,-15,76,34,77,23,-66,34,89,20,33,56,79,-21,-3};
for(int n=16;n>=0;n--)
{
selectn(arr,n);
print_n(arr,17);
}
return 0;
}
// Out:
// -3  23  12  -15  45  34  76  23  -66  34  77  20  33  56  79  -21  89
// -21  -3  12  -15  23  34  45  23  -66  34  76  20  33  56  77  79  89
// -21  -3  12  -15  23  34  45  23  -66  34  76  20  33  56  77  79  89
// -21  -3  12  -15  23  34  45  23  -66  34  56  20  33  76  77  79  89
// -21  -3  12  -15  23  33  34  23  -66  34  45  20  56  76  77  79  89
// -21  -3  12  -15  20  23  33  23  -66  34  34  45  56  76  77  79  89
// -21  -3  12  -15  20  23  33  23  -66  34  34  45  56  76  77  79  89
// -21  -3  12  -15  20  23  33  23  -66  34  34  45  56  76  77  79  89
// -66  -21  -3  -15  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -3  -15  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -3  -15  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -3  -15  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -3  -15  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89

// %%
//插入排序法
#include <stdio.h>
void swap(int* a, int*b){
int tmp = *a;
*a      = *b;
*b      = tmp;
}
void print_n(int arr[], int n){
for(int i=0;i<n;i++) printf("%d  ",arr[i]);
printf("\n");
}
void insertn(int arr[],int n,int N){
for(int j=n;j<(N-1);j++)
if(arr[j]>arr[j+1])
swap(&arr[j],&arr[j+1]);
}


int main(){
int arr[17]={45,23,12,-15,76,34,77,23,-66,34,89,20,33,56,79,-21,-3};
for(int n=16;n>=0;n--)
{
insertn(arr,n,17);
print_n(arr,17);
}
return 0;
}
// Out:
// 45  23  12  -15  76  34  77  23  -66  34  89  20  33  56  79  -21  -3
// 45  23  12  -15  76  34  77  23  -66  34  89  20  33  56  79  -21  -3
// 45  23  12  -15  76  34  77  23  -66  34  89  20  33  56  -21  -3  79
// 45  23  12  -15  76  34  77  23  -66  34  89  20  33  -21  -3  56  79
// 45  23  12  -15  76  34  77  23  -66  34  89  20  -21  -3  33  56  79
// 45  23  12  -15  76  34  77  23  -66  34  89  -21  -3  20  33  56  79
// 45  23  12  -15  76  34  77  23  -66  34  -21  -3  20  33  56  79  89
// 45  23  12  -15  76  34  77  23  -66  -21  -3  20  33  34  56  79  89
// 45  23  12  -15  76  34  77  23  -66  -21  -3  20  33  34  56  79  89
// 45  23  12  -15  76  34  77  -66  -21  -3  20  23  33  34  56  79  89
// 45  23  12  -15  76  34  -66  -21  -3  20  23  33  34  56  77  79  89
// 45  23  12  -15  76  -66  -21  -3  20  23  33  34  34  56  77  79  89
// 45  23  12  -15  -66  -21  -3  20  23  33  34  34  56  76  77  79  89
// 45  23  12  -66  -21  -15  -3  20  23  33  34  34  56  76  77  79  89
// 45  23  -66  -21  -15  -3  12  20  23  33  34  34  56  76  77  79  89
// 45  -66  -21  -15  -3  12  20  23  23  33  34  34  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89

// %%
//冒泡排序法
#include <stdio.h>
void swap(int* a, int*b){
int tmp = *a;
*a      = *b;
*b      = tmp;
}
void print_n(int arr[], int n){
for(int i=0;i<n;i++) printf("%d  ",arr[i]);
printf("\n");
}
void bubble(int arr[],int n){
for(int i=0;i<n;i++)
if(arr[i]>arr[i+1]) swap(&arr[i],&arr[i+1]);
}
int main(){
int arr[17]={45,23,12,-15,76,34,77,23,-66,34,89,20,33,56,79,-21,-3};
for(int n=16;n>=0;n--)
{
bubble(arr,n);
print_n(arr,17);
}
return 0;
}
// Out:
// 23  12  -15  45  34  76  23  -66  34  77  20  33  56  79  -21  -3  89
// 12  -15  23  34  45  23  -66  34  76  20  33  56  77  -21  -3  79  89
// -15  12  23  34  23  -66  34  45  20  33  56  76  -21  -3  77  79  89
// -15  12  23  23  -66  34  34  20  33  45  56  -21  -3  76  77  79  89
// -15  12  23  -66  23  34  20  33  34  45  -21  -3  56  76  77  79  89
// -15  12  -66  23  23  20  33  34  34  -21  -3  45  56  76  77  79  89
// -15  -66  12  23  20  23  33  34  -21  -3  34  45  56  76  77  79  89
// -66  -15  12  20  23  23  33  -21  -3  34  34  45  56  76  77  79  89
// -66  -15  12  20  23  23  -21  -3  33  34  34  45  56  76  77  79  89
// -66  -15  12  20  23  -21  -3  23  33  34  34  45  56  76  77  79  89
// -66  -15  12  20  -21  -3  23  23  33  34  34  45  56  76  77  79  89
// -66  -15  12  -21  -3  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -15  -21  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
// -66  -21  -15  -3  12  20  23  23  33  34  34  45  56  76  77  79  89
